# %% [markdown]
# # The Art of RAG Evaluation with Unstructured.io
#
# In the following notebook we'll explore the following:
#
# - Creating a simple RAG pipeline with [LangChain v0.1.0](https://blog.langchain.dev/langchain-v0-1-0/)
# - Evaluating our pipeline with the [Ragas](https://github.com/explodinggradients/ragas) library

# %%
# !pip install -U -q langchain langchain-openai langchain_core langchain-community langchainhub openai ragas tiktoken cohere faiss_cpu langchain-nomic
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 21.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 41.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 47.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 50.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.1 MB/s eta 0:00:00
#   Building wheel for nomic (setup.py) ... done

# %%
# !pip install -r /content/requirements.txt
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 2)) (0.1.13)
# Collecting unstructured[all-docs] (from -r /content/requirements.txt (line 3))
#   Downloading unstructured-0.12.6-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 4)) (1.5.3)
# Collecting jupyter (from -r /content/requirements.txt (line 5))
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirements.txt (line 1)) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->-r /content/requirements.txt (line 1)) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (0.0.29)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (0.1.31)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/requirements.txt (line 2)) (8.2.3)
# Collecting backoff==2.2.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (4.12.3)
# Requirement already satisfied: certifi==2024.2.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2024.2.2)
# Requirement already satisfied: chardet==5.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (3.3.2)
# Collecting dataclasses-json-speakeasy==0.5.11 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading dataclasses_json_speakeasy-0.5.11-py3-none-any.whl (28 kB)
# Collecting emoji==2.10.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 16.8 MB/s eta 0:00:00
# Collecting filetype==1.2.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: idna==3.6 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (3.6)
# Collecting jsonpath-python==1.0.6 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Collecting langdetect==1.0.9 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 43.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lxml==5.1.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 48.0 MB/s eta 0:00:00
# Collecting marshmallow==3.20.2 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: mypy-extensions==1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.0.0)
# Collecting numpy<2,>=1 (from langchain->-r /content/requirements.txt (line 2))
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging==23.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (23.2)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.8.2)
# Collecting python-iso639==2024.2.7 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading python_iso639-2024.2.7-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 26.5 MB/s eta 0:00:00
# Collecting python-magic==0.4.27 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting rapidfuzz==3.6.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.5 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: soupsieve==2.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.5)
# Requirement already satisfied: tabulate==0.9.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (0.9.0)
# Collecting typing-extensions==4.9.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: typing-inspect==0.9.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (0.9.0)
# Collecting unstructured-client==0.18.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading unstructured_client-0.18.0-py3-none-any.whl (21 kB)
# Collecting urllib3==1.26.18 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 15.5 MB/s eta 0:00:00
# Collecting wrapt==1.16.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock==3.13.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (3.13.1)
# Requirement already satisfied: pycocotools==2.0.7 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.0.7)
# Collecting pypandoc==1.12 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pypandoc-1.12-py3-none-any.whl (20 kB)
# Collecting humanfriendly==10.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.8 MB/s eta 0:00:00
# Collecting pypdf==4.0.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pypdf-4.0.1-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 30.7 MB/s eta 0:00:00
# Collecting pdfplumber==0.10.4 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pdfplumber-0.10.4-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 6.7 MB/s eta 0:00:00
# Collecting pdfminer-six==20221105 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 88.4 MB/s eta 0:00:00
# Collecting safetensors==0.3.2 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.3 MB/s eta 0:00:00
# Collecting msg-parser==1.2.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading msg_parser-1.2.0-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.5 MB/s eta 0:00:00
# Collecting unstructured-inference==0.7.23 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading unstructured_inference-0.7.23-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (0.12.1)
# Collecting antlr4-python3-runtime==4.9.3 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: openpyxl==3.1.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (3.1.2)
# Collecting olefile==0.47 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 14.4 MB/s eta 0:00:00
# Collecting torch==2.2.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading torch-2.2.0-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.0 MB/s eta 0:00:00
# Collecting cryptography==42.0.2 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading cryptography-42.0.2-cp39-abi3-manylinux_2_28_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 87.5 MB/s eta 0:00:00
# Collecting pikepdf==8.11.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pikepdf-8.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 81.4 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers==0.15.2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (0.15.2)
# Collecting deprecated==1.2.14 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting zipp==3.17.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting pyparsing==3.0.9 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 12.7 MB/s eta 0:00:00
# Collecting torchvision==0.17.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading torchvision-0.17.0-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 35.9 MB/s eta 0:00:00
# Requirement already satisfied: pycparser==2.21 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.21)
# Collecting pytesseract==0.3.10 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting timm==0.9.12 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 70.3 MB/s eta 0:00:00
# Collecting python-pptx==0.6.23 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading python_pptx-0.6.23-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 38.5 MB/s eta 0:00:00
# Collecting transformers==4.37.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading transformers-4.37.1-py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 90.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.3.0)
# Collecting effdet==0.4.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: markupsafe==2.1.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.1.5)
# Requirement already satisfied: et-xmlfile==1.1.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.1.0)
# Collecting omegaconf==2.3.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: xlrd==2.0.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.0.1)
# Collecting portalocker==2.8.2 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting python-docx==1.1.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading python_docx-1.1.0-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 22.4 MB/s eta 0:00:00
# Collecting pdf2image==1.17.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Collecting pillow==10.2.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 85.8 MB/s eta 0:00:00
# Collecting pillow-heif==0.15.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pillow_heif-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 96.4 MB/s eta 0:00:00
# Requirement already satisfied: fonttools==4.49.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (4.49.0)
# Collecting onnxruntime==1.15.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 57.6 MB/s eta 0:00:00
# Collecting iopath==0.1.10 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting xlsxwriter==3.1.9 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 14.6 MB/s eta 0:00:00
# Collecting onnx==1.15.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 50.5 MB/s eta 0:00:00
# Collecting tzdata==2024.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 20.6 MB/s eta 0:00:00
# Collecting scipy==1.10.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: networkx==3.2.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (3.2.1)
# Collecting protobuf==4.23.4 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 27.4 MB/s eta 0:00:00
# Collecting fsspec==2024.2.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub==0.20.3 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (0.20.3)
# Requirement already satisfied: cffi==1.16.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: kiwisolver==1.4.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.4.5)
# Collecting matplotlib (from -r /content/requirements.txt (line 6))
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 81.6 MB/s eta 0:00:00
# Collecting pandas (from -r /content/requirements.txt (line 4))
#   Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 96.6 MB/s eta 0:00:00
# Collecting importlib-metadata==7.0.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Collecting layoutparser[layoutmodels,tesseract]==0.3.4 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 64.9 MB/s eta 0:00:00
# Requirement already satisfied: contourpy==1.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.2.0)
# Collecting pypdfium2==4.27.0 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pypdfium2-4.27.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 86.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python==4.8.0.76 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (4.8.0.76)
# Collecting pytz==2024.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 42.7 MB/s eta 0:00:00
# Collecting flatbuffers==23.5.26 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting importlib-resources==6.1.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: jinja2==3.1.3 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (3.1.3)
# Collecting python-multipart==0.0.9 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: sympy==1.12 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]->-r /content/requirements.txt (line 3)) (1.12)
# Collecting markdown==3.5.2 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading Markdown-3.5.2-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 kB 11.3 MB/s eta 0:00:00
# Collecting coloredlogs==15.0.1 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.7 MB/s eta 0:00:00
# Collecting unstructured-pytesseract==0.3.12 (from unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 21.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 47.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 83.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.9 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3)) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.0->unstructured[all-docs]->-r /content/requirements.txt (line 3))
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->-r /content/requirements.txt (line 5)) (6.5.5)
# Collecting qtconsole (from jupyter->-r /content/requirements.txt (line 5))
#   Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->-r /content/requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->-r /content/requirements.txt (line 5)) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->-r /content/requirements.txt (line 5)) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->-r /content/requirements.txt (line 5)) (7.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/requirements.txt (line 2)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/requirements.txt (line 2)) (1.9.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain->-r /content/requirements.txt (line 2)) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.33->langchain->-r /content/requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain->-r /content/requirements.txt (line 2)) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain->-r /content/requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain->-r /content/requirements.txt (line 2)) (2.16.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r /content/requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->-r /content/requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->-r /content/requirements.txt (line 5)) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->-r /content/requirements.txt (line 5)) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->-r /content/requirements.txt (line 5)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->-r /content/requirements.txt (line 5)) (6.3.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->-r /content/requirements.txt (line 5)) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->-r /content/requirements.txt (line 5)) (3.0.10)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->-r /content/requirements.txt (line 5)) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter->-r /content/requirements.txt (line 5)) (2.16.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (5.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->-r /content/requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->-r /content/requirements.txt (line 5)) (1.0.0)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter->-r /content/requirements.txt (line 5))
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain->-r /content/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.33->langchain->-r /content/requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->-r /content/requirements.txt (line 5)) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->-r /content/requirements.txt (line 5)) (0.2.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (4.19.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->-r /content/requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->jupyter->-r /content/requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->-r /content/requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->-r /content/requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->-r /content/requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /content/requirements.txt (line 5)) (1.7.0)
# Building wheels for collected packages: antlr4-python3-runtime, iopath, langdetect
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=949449f20b8c7e1746debae43d6e9e4b635681b2f024684e09df614779e8bc4d
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=d33792fa5c894efc0f3237ec9cc02cfe172561a572547e0d11c31a40b8a9a996
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=27a49298ae0db439d9a8d01f40ae5d19010cd59cb2894f79f4003fd38a8e6839
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built antlr4-python3-runtime iopath langdetect
# Installing collected packages: safetensors, pytz, flatbuffers, filetype, antlr4-python3-runtime, zipp, xlsxwriter, wrapt, urllib3, tzdata, typing-extensions, rapidfuzz, qtpy, python-multipart, python-magic, python-iso639, pypdfium2, pypdf, pyparsing, pypandoc, protobuf, portalocker, pillow, omegaconf, olefile, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, marshmallow, markdown, lxml, langdetect, jsonpath-python, jedi, importlib-resources, humanfriendly, fsspec, emoji, backoff, unstructured-pytesseract, scipy, python-pptx, python-docx, pytesseract, pillow-heif, pdf2image, pandas, onnx, nvidia-cusparse-cu12, nvidia-cudnn-cu12, msg-parser, iopath, importlib-metadata, deprecated, cryptography, coloredlogs, pikepdf, pdfminer-six, onnxruntime, nvidia-cusolver-cu12, matplotlib, dataclasses-json-speakeasy, unstructured-client, torch, qtconsole, pdfplumber, unstructured, transformers, torchvision, layoutparser, timm, effdet, unstructured-inference, jupyter
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.2
#     Uninstalling safetensors-0.4.2:
#       Successfully uninstalled safetensors-0.4.2
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.4
#     Uninstalling pytz-2023.4:
#       Successfully uninstalled pytz-2023.4
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 24.3.7
#     Uninstalling flatbuffers-24.3.7:
#       Successfully uninstalled flatbuffers-24.3.7
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.18.1
#     Uninstalling zipp-3.18.1:
#       Successfully uninstalled zipp-3.18.1
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: marshmallow
#     Found existing installation: marshmallow 3.21.1
#     Uninstalling marshmallow-3.21.1:
#       Successfully uninstalled marshmallow-3.21.1
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.6
#     Uninstalling Markdown-3.6:
#       Successfully uninstalled Markdown-3.6
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.4
#     Uninstalling lxml-4.9.4:
#       Successfully uninstalled lxml-4.9.4
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib_resources 6.3.0
#     Uninstalling importlib_resources-6.3.0:
#       Successfully uninstalled importlib_resources-6.3.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 7.0.2
#     Uninstalling importlib_metadata-7.0.2:
#       Successfully uninstalled importlib_metadata-7.0.2
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 42.0.5
#     Uninstalling cryptography-42.0.5:
#       Successfully uninstalled cryptography-42.0.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.17.1+cu121
#     Uninstalling torchvision-0.17.1+cu121:
#       Successfully uninstalled torchvision-0.17.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.25.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.0 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.2.0 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.0 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# tensorflow 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.16.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.2.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.2.0 which is incompatible.
# types-requests 2.31.0.20240311 requires urllib3>=2, but you have urllib3 1.26.18 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 backoff-2.2.1 coloredlogs-15.0.1 cryptography-42.0.2 dataclasses-json-speakeasy-0.5.11 deprecated-1.2.14 effdet-0.4.1 emoji-2.10.1 filetype-1.2.0 flatbuffers-23.5.26 fsspec-2024.2.0 humanfriendly-10.0 importlib-metadata-7.0.1 importlib-resources-6.1.1 iopath-0.1.10 jedi-0.19.1 jsonpath-python-1.0.6 jupyter-1.0.0 langdetect-1.0.9 layoutparser-0.3.4 lxml-5.1.0 markdown-3.5.2 marshmallow-3.20.2 matplotlib-3.7.2 msg-parser-1.2.0 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 olefile-0.47 omegaconf-2.3.0 onnx-1.15.0 onnxruntime-1.15.1 pandas-2.2.0 pdf2image-1.17.0 pdfminer-six-20221105 pdfplumber-0.10.4 pikepdf-8.11.0 pillow-10.2.0 pillow-heif-0.15.0 portalocker-2.8.2 protobuf-4.23.4 pypandoc-1.12 pyparsing-3.0.9 pypdf-4.0.1 pypdfium2-4.27.0 pytesseract-0.3.10 python-docx-1.1.0 python-iso639-2024.2.7 python-magic-0.4.27 python-multipart-0.0.9 python-pptx-0.6.23 pytz-2024.1 qtconsole-5.5.1 qtpy-2.4.1 rapidfuzz-3.6.1 safetensors-0.3.2 scipy-1.10.1 timm-0.9.12 torch-2.2.0 torchvision-0.17.0 transformers-4.37.1 typing-extensions-4.9.0 tzdata-2024.1 unstructured-0.12.6 unstructured-client-0.18.0 unstructured-inference-0.7.23 unstructured-pytesseract-0.3.12 urllib3-1.26.18 wrapt-1.16.0 xlsxwriter-3.1.9 zipp-3.17.0

# %%
import langchain
print(f"LangChain Version: {langchain.__version__}")
# Out:
# LangChain Version: 0.1.13

# %%
from langchain_community.document_loaders import UnstructuredFileLoader

loader = UnstructuredFileLoader(
    "/content/DoD_Data_Strategy.pdf", mode="elements"
)
docs = loader.load()
docs[:5]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [Document(page_content='Executive Summary: DoD Data Strategy Unleashing Data to Advance the National Defense Strategy', metadata={'source': '/content/DoD_Data_Strategy.pdf', 'coordinates': {'points': ((134.66, 74.58800000000008), (134.66, 110.45263999999997), (484.33, 110.45263999999997), (484.33, 74.58800000000008)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': '/content', 'filename': 'DoD_Data_Strategy.pdf', 'languages': ['eng'], 'last_modified': '2024-03-20T23:43:45', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'UncategorizedText'}),
#  Document(page_content='BLUF: The DoD Data Strategy supports the National Defense Strategy and Digital Modernization by providing the overarching vision, focus areas, guiding principles, essential capabilities, and goals necessary to transform the Department into a data-centric enterprise. Success cannot be taken for granted…it is the responsibility of all DoD leaders to treat data as a weapon system and manage, secure, and use data for operational effect.', metadata={'source': '/content/DoD_Data_Strategy.pdf', 'coordinates': {'points': ((54.0, 128.33264000000008), (54.0, 206.81264), (561.61, 206.81264), (561.61, 128.33264000000008)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': '/content', 'filename': 'DoD_Data_Strategy.pdf', 'languages': ['eng'], 'last_modified': '2024-03-20T23:43:45', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'NarrativeText'}),
#  Document(page_content='Vision: DoD is a data-centric organization that uses data at speed and scale for operational advantage and increased efficiency.', metadata={'source': '/content/DoD_Data_Strategy.pdf', 'coordinates': {'points': ((54.0, 216.89264000000003), (54.0, 247.01264000000003), (561.2047080799998, 247.01264000000003), (561.2047080799998, 216.89264000000003)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': '/content', 'filename': 'DoD_Data_Strategy.pdf', 'languages': ['eng'], 'last_modified': '2024-03-20T23:43:45', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'NarrativeText'}),
#  Document(page_content='Focus Areas: The strategy emphasizes the need to work closely with users in the operational community, particularly the warfighter. Initial areas of focus include:', metadata={'source': '/content/DoD_Data_Strategy.pdf', 'coordinates': {'points': ((54.0, 257.00264000000004), (54.0, 287.24264), (561.1769867599999, 287.24264), (561.1769867599999, 257.00264000000004)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': '/content', 'filename': 'DoD_Data_Strategy.pdf', 'languages': ['eng'], 'last_modified': '2024-03-20T23:43:45', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'NarrativeText'}),
#  Document(page_content='Joint All Domain Operations – using data for advantage on the battlefield - Senior Leader Decision Support – using data to improve DoD management - Business Analytics – using data to drive informed decisions at all echelons', metadata={'source': '/content/DoD_Data_Strategy.pdf', 'coordinates': {'points': ((72.024, 295.1984), (72.024, 341.48264), (515.0500000000001, 341.48264), (515.0500000000001, 295.1984)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': '/content', 'filename': 'DoD_Data_Strategy.pdf', 'languages': ['eng'], 'last_modified': '2024-03-20T23:43:45', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'ListItem'})]

# %% [markdown]
# Since we'll be using OpenAI to power our RAG pipeline and part of the functionality of the RAGAS library - we'll need an OpenAI API key!

# %%
import os
import openai
from getpass import getpass

openai.api_key = getpass("Please provide your OpenAI Key: ")
os.environ["OPENAI_API_KEY"] = openai.api_key
# Out:
# Please provide your OpenAI Key: ··········

# %% [markdown]
# ## Building our RAG pipeline
#
# While the version may have changed - the process of creating our RAG pipeline remains largely the same:
#
# - Create an Index
# - Use a LLM to generate responses based on the retrieved context
#
# Let's get started by creating our index.

# %% [markdown]
# ### Creating an Index
#
# You'll notice that the largest changes (outside of some import changes) are that our old favourite chains are back to being bundled in an easily usable abstraction.
#
# We can still create custom chains using LCEL - but we can also be more confident that our pre-packaged chains are creating using LCEL under the hood.

# %% [markdown]
# #### Loading Data
#
# Let's start by loading some data - we'll be using the LangChain v0.1.0 blog to both keep things simple, and keep things meta.
#
# > NOTE: You'll notice that some specific loaders, LLMs, etc., are in their own libraries now. This allows you to stay as lightweight as you'd like while using LangChain!

# %% [markdown]
# #### Transforming Data
#
# Now that we've got our single document - let's split it into smaller pieces so we can more effectively leverage it with our retrieval chain!
#
# We'll start with the classic: `RecursiveCharacterTextSplitter`.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 700,
    chunk_overlap = 50
)

documents = text_splitter.split_documents(docs)

# %% [markdown]
# Let's confirm we've split our document.

# %%
len(documents)
# Out:
# 349

# %% [markdown]
# #### Loading OpenAI Embeddings Model
#
# We'll need a process by which we can convert our text into vectors that allow us to compare to our query vector.
#
# Let's use OpenAI's `text-embedding-ada-002` for this task! (soon we'll be able to leverage OpenAI's newest embedding model which is waiting on an approved PR to be merged as we speak!)

# %%
from langchain_nomic import NomicEmbeddings

embeddings = NomicEmbeddings(
    model="nomic-embed-text-v1.5"
)

# %%
! nomic login nk-VVMBchiQLy7Jk-9Tuq9Ig8faaAtZCVrnXsH7RmAye7I

# %% [markdown]
# #### Creating a FAISS VectorStore
#
# Now that we have documents - we'll need a place to store them alongside their embeddings.
#
# We'll be leveraging Meta's FAISS for this task.

# %%
from langchain_community.vectorstores import FAISS

vector_store = FAISS.from_documents(documents, embeddings)

# %% [markdown]
# #### Creating a Retriever
#
# To complete our index, all that's left to do is expose our vectorstore as a retriever - which we can do the same way we would in previous version of LangChain!

# %%
retriever = vector_store.as_retriever()

# %% [markdown]
# ### Creating a RAG Chain
#
# Now that we have the "R" in RAG taken care of - let's look at creating the "AG"!

# %% [markdown]
# #### Creating a Prompt Template
#
# There are a few different ways we could create our prompt template - we could create a custom template, as seen in the code below, or we could simply pull a prompt from the prompt hub! Let's look at an example of that!

# %%
from langchain import hub

retrieval_qa_prompt = hub.pull("langchain-ai/retrieval-qa-chat")

# %%
print(retrieval_qa_prompt.messages[0].prompt.template)
# Out:
# Answer any use questions based solely on the context below:
#
# <context>
# {context}
# </context>

# %% [markdown]
# As you can see - the prompt template is simple - but we'll create our own to be a bit more specific!

# %%
from langchain.prompts import ChatPromptTemplate

template = """Answer the question based only on the following context. If you cannot answer the question with the context, please respond with 'I don't know':

Context:
{context}

Question:
{question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %% [markdown]
# #### Setting Up our Basic QA Chain
#
# Now we can instantiate our basic RAG chain!
#
# We'll use LCEL directly just to see an example of it - but you could just as easily use an abstraction here to achieve the same goal!
#
# We'll also ensure to pass-through our context - which is critical for RAGAS.

# %%
from operator import itemgetter

from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

retrieval_augmented_qa_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": prompt | primary_qa_llm, "context": itemgetter("context")}
)

# %% [markdown]
# ## Ragas Evaluation
#
# Ragas is a powerful library that lets us evaluate our RAG pipeline by collecting input/output/context triplets and obtaining metrics relating to a number of different aspects of our RAG pipeline.
#
# We'll be evluating on every core metric today, but in order to do that - we'll need to creat a test set. Luckily for us, Ragas can do that directly!

# %% [markdown]
# #### Synthetic Test Set Generation
#
# We can leverage Ragas' [`Synthetic Test Data generation`](https://docs.ragas.io/en/stable/concepts/testset_generation.html) functionality to generate our own synthetic QC pairs - as well as a synthetic ground truth - quite easily!
#
# > NOTE: This process will use `gpt-3.5-turbo-16k` as the base generator and `gpt-4` as the critic - if you're attempting to create a lot of samples please be aware of cost, as well as rate limits.

# %% [markdown]
# Let's create a new set of documents to ensure we're not accidentally creating a sample test set that favours our base model too much!

# %%
documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 200
)
documents = text_splitter.split_documents(documents)

# %%
len(documents)
# Out:
# 339

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

generator = TestsetGenerator.with_openai()

testset = generator.generate_with_langchain_docs(documents, test_size=10, distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25})
# Out:
# <ipython-input-16-6bb4ddca3d40>:4: DeprecationWarning: The function with_openai was deprecated in 0.1.4, and will be removed in the 0.2.0 release. Use from_langchain instead.
#   generator = TestsetGenerator.with_openai()
# embedding nodes:   0%|          | 0/678 [00:00<?, ?it/s]
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Let's look at the output and see what we can learn about it!

# %%
testset.test_data[0]
# Out:
# DataRow(question='How do data catalogs contribute to data-driven decision-making in the Department of Defense?', contexts=['Data-driven decision-making requires DoD data to be linked such that relationships and dependencies can be uncovered and maintained. Adhering to industry best-practices for open data standards, data catalogs, and metadata tagging, the Department ensures that connections across disparate sources can be made and leveraged for analytics.'], ground_truth='Data catalogs contribute to data-driven decision-making in the Department of Defense by adhering to industry best-practices for open data standards, data catalogs, and metadata tagging. This ensures that connections across disparate sources can be made and leveraged for analytics.', evolution_type='simple', metadata=[{'source': '/content/DoD_Data_Strategy.pdf', 'coordinates': {'points': ((72.024, 138.452), (72.024, 191.85199999999998), (543.3159999999999, 191.85199999999998), (543.3159999999999, 138.452)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': '/content', 'filename': 'DoD_Data_Strategy.pdf', 'languages': ['eng'], 'last_modified': '2024-03-20T23:43:45', 'page_number': 13, 'parent_id': '91df6a0532fae4bc5add0d232d5fe6d7', 'filetype': 'application/pdf', 'category': 'NarrativeText'}])

# %% [markdown]
# #### Generating Responses with RAG Pipeline
#
# Now that we have some QC pairs, and some ground truths, let's evaluate our RAG pipeline using Ragas.
#
# The process is, again, quite straightforward - thanks to Ragas and LangChain!
#
# Let's start by extracting our questions and ground truths from our create testset.
#
# We can start by converting our test dataset into a Pandas DataFrame.

# %%
test_df = testset.to_pandas()

# %%
test_df
# Out:
#                                             question  \
# 0  How do data catalogs contribute to data-driven...
# 1  How does superior situational awareness contri...
# 2  How does DoD research contribute to the transi...
# 3  How does the Department of Defense plan to cul...
# 4  What is the purpose of developing measurable D...
# 5  How do algorithmic models contribute to AI int...
# 6  What characteristics make data a strategic ass...
# 7  How do principles in data governance contribut...
# 8  How can user feedback and ongoing initiatives ...
# 9  What is the role of data governance in managin...
#
#                                             contexts  \
# 0  [Data-driven decision-making requires DoD data...
# 1  [Warfighters at all echelons require tested, s...
# 2  [When new data gaps are identified, the data g...
# 3  [Moving the Department to a data-centric organ...
# 4  [Way Ahead: To implement this Strategy, Compon...
# 5  [Artificial Intelligence (AI) is a long-term d...
# 6  [A core tenet of the DoD Data Strategy is the ...
# 7  [Data governance provides the principles, poli...
# 8  [Data policies and standards alone cannot stre...
# 9  [Data governance provides the principles, poli...
#
#                                         ground_truth evolution_type  \
# 0  Data catalogs contribute to data-driven decisi...         simple
# 1  Superior situational awareness contributes to ...         simple
# 2                                                nan         simple
# 3  The Department of Defense plans to cultivate d...         simple
# 4  The purpose of developing measurable Data Stra...         simple
# 5  Algorithmic models contribute to AI integratio...      reasoning
# 6  Data is considered a strategic asset for the D...      reasoning
# 7                                                nan  multi_context
# 8  User feedback and ongoing initiatives can impr...  multi_context
# 9  Data governance provides the principles, polic...      reasoning
#
#                                             metadata  episode_done
# 0  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 1  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 2  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 3  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 4  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 5  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 6  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 7  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 8  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True
# 9  [{'source': '/content/DoD_Data_Strategy.pdf', ...          True

# %%
test_questions = test_df["question"].values.tolist()
test_groundtruths = test_df["ground_truth"].values.tolist()

# %% [markdown]
# Now we'll generate responses using our RAG pipeline using the questions we've generated - we'll also need to collect our retrieved contexts for each question.
#
# We'll do this in a simple loop to see exactly what's happening!

# %%
answers = []
contexts = []

for question in test_questions:
  response = retrieval_augmented_qa_chain.invoke({"question" : question})
  answers.append(response["response"].content)
  contexts.append([context.page_content for context in response["context"]])

# %% [markdown]
# Now we can wrap our information in a Hugging Face dataset for use in the Ragas library.

# %%
from datasets import Dataset

response_dataset = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %% [markdown]
# Let's take a peek and see what that looks like!

# %%
response_dataset[0]
# Out:
# {'question': 'How do data catalogs contribute to data-driven decision-making in the Department of Defense?',
#  'answer': 'Data catalogs contribute to data-driven decision-making in the Department of Defense by ensuring that connections across disparate sources can be made and leveraged for analytics.',
#  'contexts': ['Data-driven decision-making requires DoD data to be linked such that relationships and dependencies can be uncovered and maintained. Adhering to industry best-practices for open data standards, data catalogs, and metadata tagging, the Department ensures that connections across disparate sources can be made and leveraged for analytics.',
#   'Moving the Department to a data-centric organization requires a cultural transformation with the DoD workforce at its heart. DoD will continue to evolve its decision-making culture to one soundly based upon data and analytics enabled by technology. A modern, agile, information-advantaged DoD workforce (leaders, service members, civilians, and contractors) will be increasingly empowered to work with data, make data-informed decisions, create evidence-based policies, and implement effectual processes. We must carefully cultivate our data talent to create and sustain these capabilities. We must provide data skill training, establish centers for data engineering excellence, and foster a',
#   'DoD supports data exploration to enhance analyses that impact decision making.',
#   'Data underpins digital modernization and is increasingly the fuel of every DoD process, algorithm, and weapon system. The DoD Data Strategy describes an ambitious approach for transforming the Department into a data-driven organization. This requires strong and effective data management coupled with close partnerships with users, particularly warfighters. Every leader must treat data as a weapon system, stewarding data throughout its lifecycle and ensuring it is made available to others. The Department must provide its personnel with the modern data skills and tools to preserve U.S. military advantage in day-to-day competition and ensure that they can prevail in conflict.'],
#  'ground_truth': 'Data catalogs contribute to data-driven decision-making in the Department of Defense by adhering to industry best-practices for open data standards, data catalogs, and metadata tagging. This ensures that connections across disparate sources can be made and leveraged for analytics.'}

# %% [markdown]
# #### Evaluating with Ragas
#
# Now that we have our response dataset - we can finally get into the "meat" of Ragas - evaluation!
#
# First, we'll import the desired metrics, then we can use them to evaluate our created dataset!
#
# Check out the specific metrics we'll be using in the Ragas documentation:
#
# - [Faithfulness](https://docs.ragas.io/en/stable/concepts/metrics/faithfulness.html)
# - [Answer Relevancy](https://docs.ragas.io/en/stable/concepts/metrics/answer_relevance.html)
# - [Context Precision](https://docs.ragas.io/en/stable/concepts/metrics/context_precision.html)
# - [Context Recall](https://docs.ragas.io/en/stable/concepts/metrics/context_recall.html)
# - [Answer Correctness](https://docs.ragas.io/en/stable/concepts/metrics/answer_correctness.html)
#
# See the accompanied presentation for more in-depth explanations about each of the metrics!

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %% [markdown]
# All that's left to do is call "evaluate" and away we go!

# %%
results = evaluate(response_dataset, metrics)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
results
# Out:
# {'faithfulness': 1.0000, 'answer_relevancy': 0.8704, 'context_recall': 1.0000, 'context_precision': 0.7750, 'answer_correctness': 0.5451}

# %%
results_df = results.to_pandas()
results_df
# Out:
#                                             question  \
# 0  How do data catalogs contribute to data-driven...
# 1  How does superior situational awareness contri...
# 2  How does DoD research contribute to the transi...
# 3  How does the Department of Defense plan to cul...
# 4  What is the purpose of developing measurable D...
# 5  How do algorithmic models contribute to AI int...
# 6  What characteristics make data a strategic ass...
# 7  How do principles in data governance contribut...
# 8  How can user feedback and ongoing initiatives ...
# 9  What is the role of data governance in managin...
#
#                                               answer  \
# 0  Data catalogs contribute to data-driven decisi...
# 1  Superior situational awareness contributes to ...
# 2                                      I don't know.
# 3  The Department of Defense plans to cultivate d...
# 4  The purpose of developing measurable Data Stra...
# 5  Algorithmic models contribute to AI integratio...
# 6  Data is considered a strategic asset for the D...
# 7  Principles in data governance contribute to th...
# 8  User feedback and ongoing initiatives can impr...
# 9  The role of data governance is to provide the ...
#
#                                             contexts  \
# 0  [Data-driven decision-making requires DoD data...
# 1  [Warfighters at all echelons require tested, s...
# 2  [Moving the Department to a data-centric organ...
# 3  [Moving the Department to a data-centric organ...
# 4  [Way Ahead: To implement this Strategy, Compon...
# 5  [algorithmic models will increasingly become t...
# 6  [A core tenet of the DoD Data Strategy is the ...
# 7  [Data policies and standards alone cannot stre...
# 8  [Data policies and standards alone cannot stre...
# 9  [Data governance provides the principles, poli...
#
#                                         ground_truth  faithfulness  \
# 0  Data catalogs contribute to data-driven decisi...           1.0
# 1  Superior situational awareness contributes to ...           1.0
# 2                                                nan           NaN
# 3  The Department of Defense plans to cultivate d...           1.0
# 4  The purpose of developing measurable Data Stra...           1.0
# 5  Algorithmic models contribute to AI integratio...           1.0
# 6  Data is considered a strategic asset for the D...           1.0
# 7                                                nan           1.0
# 8  User feedback and ongoing initiatives can impr...           1.0
# 9  Data governance provides the principles, polic...           1.0
#
#    answer_relevancy  context_recall  context_precision  answer_correctness
# 0          1.000000             1.0           0.750000            0.742591
# 1          1.000000             1.0           1.000000            0.674351
# 2          0.000000             1.0           0.000000            0.198202
# 3          0.967799             1.0           1.000000            0.621262
# 4          0.968797             1.0           0.916667            0.532234
# 5          0.940402             1.0           0.583333            0.432678
# 6          0.959596             1.0           1.000000            0.998678
# 7          0.952556             1.0           0.500000            0.175878
# 8          1.000000             1.0           1.000000            0.460651
# 9          0.915233             1.0           1.000000            0.614657
